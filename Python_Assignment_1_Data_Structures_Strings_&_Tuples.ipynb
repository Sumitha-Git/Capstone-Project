# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumitha-Git/Capstone-Project/blob/main/Python_Assignment_1_Data_Structures_Strings_%26_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Module - 4 - Python Assignment 1 - Data Structures - Strings & Tuples

# %%
# Strings
# '' - Normal word we should use this quotes
# "" - Single line & If any Apostrophe Words, we should use this quotes
# """ """ - Mulitple Line & Paragraph, we should use this quotes

# %%
# 1. String Concatenation:

# %%
string1 = "Hello"
print(string1)
# Out:
# Hello

# %%
string2 = input("Enter your Name: ")
print(string2)
# Out:
# Enter your Name: Zara
# Zara

# %%
s1 = string1 +" " + string2

print(s1)
# Out:
# Hello Zara

# %%
string3 = "welcome to Python programming"
print(string3)
# Out:
# welcome to Python programming

# %%
s2 = string1 +" " + string2 +", "+ string3
print(s2)
# Out:
# Hello Zara, welcome to Python programming

# %%
# 2. String Slicing and Indexing:

# %%
f1 = "Python"
print(f1[0])
print(f1[-1])
# Out:
# P
# n

# %%
print(f1[0:5])
# Out:
# Pytho

# %%
f2 = "Welcome to Python programming"
print(f2[-11 :])
# Out:
# programming

# %%
print(f2[: : -1])
# Out:
# gnimmargorp nohtyP ot emocleW

# %%
print(f2[11:17])
# Out:
# Python

# %%
# 3. String Methods :

# %%
strM = "Python beginner tutorial,"
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL,

# %%
print(strM.lower())
# Out:
# python beginner tutorial,

# %%
print (strM.capitalize())
# Out:
# Python beginner tutorial,

# %%
print(strM.count("t"))
# Out:
# 3

# %%
strM = "Python beginner tutorial"

new = strM.replace("Python", "Data Analytics")

print(new)
# Out:
# Data Analytics beginner tutorial

# %%
# 4.Tuples (Creation, Modification and Access) :

# %%
mark1 = 10,20,30
mark2 = 40,50,60
print(mark1)
print(mark2)
# Out:
# (10, 20, 30)
# (40, 50, 60)

# %%
t_combine = mark1 + mark2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
repete = t_combine * 3
print(repete)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
